# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinz1098/Discord_PudgyPenguins/blob/main/Step_1_Extracted_Discord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)

# %%
import requests
import json

def retrieve_messages(channelid):
    headers = {
        'authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'
    }
    url = f'https://discord.com/api/v9/channels/1187747399981088909/messages'
    r = requests.get(url, headers=headers)

    if r.status_code == 200:
        json_data = json.loads(r.text)
        for message in json_data:
            print(message['content'])
    else:
        print(f"Failed to retrieve messages. Status code: {r.status_code}")

retrieve_messages('1187747399981088909')
# Out:
# successfully got the messages from dec2023, but taking too time to download in excel file.
# You did not specify a specific date range. Can you specify a date range? But make it just 1 day range.
# I could only able to retrieve the latest messages, not the earliest dates.
# ok
# Break and extract for a single day
# Just extract for one day
# Hi team,
# I'm trying to retrieve the "huddle chat" discord channel, but it's not showing the output as, it taking too long to output to process due the large volume of data. I have also created a loop and also tried to make the timeline lesser to get the data. but still processing...
# Shall we fix a meet for today?
# Hi Vinayak - the next payroll day is Jan. 26th when you get paid on this date please log on to employee self service here https://www.maynoothuniversity.ie/human-resources/employee-self-service-ess and check your payslip to make sure you have been switched to full time hours and ideally back paid for full time hours since Dec. 1st 2023
# Hi team,  I’m already joined in meet.
#
# I extracted all the discord announcement till date.
# Here it's to be noted that most the data are provided with twitter links, like the master post are from twitter accounts only.
# Keep extracting
# Cool that’s a good start
# It's just from 16th july 2022 onwards.
# Sure, you may just need to insert a timer for a few seconds between each batch of calls
# there is limit in extracting the dataset in one go, but I'll send whtever extracted till now.
# The dataset …
# https://colab.research.google.com/drive/1e_OO2zly0G-tfIE_MZFjnKooXqHmUqWh?usp=sharing
# sure. No problem.
# Can you send the data you extracted from discord?
# Sorry Vinz, we’ll chat tomorrow.
# Hi team,
# just a quick reminder!! to provide a meeting link.
#
# Thanks!
# https://colab.research.google.com/drive/1vLByMooQYkMYAxld9kDito79Ce46J08E?usp=sharing
# ok thanks
# Available for quick one between 4.30 - 5p.
# Hi team, Is it possible to schedule a quick meet for today?
# You could work one day’s archive at a time. So grab just one day’s archive and process.
# This error persist in every single execution.
# Thanks
# Really good
# from announcement id, frm the date 16/07/2022  to the latest.
# Very good. How many posts did you grab?
# Dicord one. now will try Tweet
# Discord or Tweet archive
# Good progress Vinz, from which source?
# https://colab.research.google.com/drive/1e_OO2zly0G-tfIE_MZFjnKooXqHmUqWh?usp=sharing
# Hi team,
# I managed to grab the pudgy penguins data, but there's a hitch: I couldn't get all the data from just one go. I will be sharing my work here and through mail.
# Thanks <@718402724609130506>
# <@1165957693702418443>  here are the python script and description
# hello all!

# %%
import requests
import json

def retrieve_messages(channelid):
    headers = {
        'authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'
    }
    url = f'https://discord.com/api/v9/channels/867770503842234398/messages'
    r = requests.get(url, headers=headers)

    if r.status_code == 200:
        json_data = json.loads(r.text)
        for message in json_data:
            print(message['content'])
    else:
# <https://twitter.com/pudgypenguins/status/1715840163316666686>
# 📰🐧<@&997907653227450458>
# <https://twitter.com/pudgypenguins/status/1713972384112201798>
# 📰🐧<@&997907653227450458>
# <https://twitter.com/pudgypenguins/status/1712945945736867882>
# 📰🐧<@&997907653227450458>
# <https://twitter.com/pudgypenguins/status/1711836158756327866>
# 📰🐧<@&997907653227450458>
# <https://twitter.com/pudgypenguins/status/1711836152238313556>
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1708935171271950756
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1706805750574743650
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1705703905458311678
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1704981129315365047
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1703876678672318535
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1700255216506134645
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1696194400651542977
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1694730462487564350
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1694032416044691805
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1691546342336663553
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1689091834792890368
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1671987896398802955
# 📰🐧<@&997907653227450458>
# https://twitter.com/pudgypenguins/status/1671987893676699650

# %%
import requests
import json
import pandas as pd

def retrieve_messages_with_user(channel_id):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }
    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    params = {
        'limit': 100  # Number of messages per request, adjust as needed
    }
    all_messages = []

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break  # Break the loop if no more messages
            all_messages.extend(json_data)
            params['before'] = json_data[-1]['id']  # Set the 'before' parameter for pagination
        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return

    messages_data = []
    for message in all_messages:
        content = message['content']
        timestamp = message['timestamp']  # Get the timestamp of the message
        user_id = message['author']['id'] if 'author' in message else None  # Get user ID
        messages_data.append({'Timestamp': timestamp, 'Content': content, 'User_ID': user_id})

    # Convert data to DataFrame
    df = pd.DataFrame(messages_data)

    # Export to Excel
    file_name = 'discord_messages_announcements_with_users.xlsx'  # Change the file name if needed
    df.to_excel(file_name, index=False)
    print(f"Messages successfully saved to {file_name}")

retrieve_messages_with_user('865677053567565854')
# Out:
# Messages successfully saved to discord_messages_announcements_with_users.xlsx

# %%
import requests
import json
import pandas as pd

def retrieve_messages(channel_id):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }
    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    params = {
        'limit': 100  # Number of messages per request, adjust as needed
    }
    all_messages = []

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break  # Break the loop if no more messages
            all_messages.extend(json_data)
            params['before'] = json_data[-1]['id']  # Set the 'before' parameter for pagination
        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return

    messages_data = []
    for message in all_messages:
        content = message['content']
        timestamp = message['timestamp']  # Get the timestamp of the message
        messages_data.append({'Timestamp': timestamp, 'Content': content})

    # Convert data to DataFrame
    df = pd.DataFrame(messages_data)

    # Export to Excel
    file_name = 'discord_messages_Socials.xlsx'  # Change the file name if needed
    df.to_excel(file_name, index=False)
    print(f"Messages successfully saved to {file_name}")

retrieve_messages('867770503842234398')
# Out:
# Messages successfully saved to discord_messages_Socials.xlsx

# %%
import requests
import json
import pandas as pd

def retrieve_messages(channel_id):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }
    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    params = {
        'limit': 100  # Number of messages per request, adjust as needed
    }
    all_messages = []

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break  # Break the loop if no more messages
            all_messages.extend(json_data)
            params['before'] = json_data[-1]['id']  # Set the 'before' parameter for pagination
        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return

    messages_data = []
    for message in all_messages:
        content = message['content']
        timestamp = message['timestamp']  # Get the timestamp of the message
        messages_data.append({'Timestamp': timestamp, 'Content': content})

    # Convert data to DataFrame
    df = pd.DataFrame(messages_data)

    # Export to Excel
    file_name = 'discord_messages_productupdates.xlsx'  # Change the file name if needed
    df.to_excel(file_name, index=False)
    print(f"Messages successfully saved to {file_name}")

retrieve_messages('1039635256585760778')
# Out:
# Messages successfully saved to discord_messages_productupdates.xlsx

# %%
import requests
import json

def retrieve_messages(channel_id):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }
    url = f'https://discord.com/api/v9/channels/867732042325688350/messages'
    r = requests.get(url, headers=headers)

    if r.status_code == 200:
        json_data = r.json()
        for message in json_data:
            content = message['content']
            timestamp = message['timestamp']  # Get the timestamp of the message
            print(f"Timestamp: {timestamp}, Content: {content}")

retrieve_messages('867732042325688350')
# Out:
# Timestamp: 2024-01-10T12:16:46.723000+00:00, Content: https://tenor.com/view/no-nope-not-today-reject-denied-gif-12847502466917853549
# Timestamp: 2024-01-10T12:16:20.837000+00:00, Content: Gm
# Timestamp: 2024-01-10T12:16:16.513000+00:00, Content: A lil pudgy?
# Timestamp: 2024-01-10T12:15:19.783000+00:00, Content: Anyone want to trade for CloneX?
# Timestamp: 2024-01-10T12:12:43.885000+00:00, Content:
# Timestamp: 2024-01-10T12:12:26.594000+00:00, Content:
# Timestamp: 2024-01-10T07:24:51.951000+00:00, Content: Those Apes must’ve did this
# Timestamp: 2024-01-10T07:24:39.560000+00:00, Content: https://tenor.com/view/angry-fire-upset-election-penguin-gif-18223920717933682527
# Timestamp: 2024-01-10T07:13:13.083000+00:00, Content: Just opened my eyes
# Timestamp: 2024-01-10T07:13:06.383000+00:00, Content: Hi sauci gm
# Timestamp: 2024-01-10T07:12:47.332000+00:00, Content: gm
# Timestamp: 2024-01-10T07:12:36.295000+00:00, Content: <a:beccawave:1187788228447711262>
# Timestamp: 2024-01-10T07:12:25.523000+00:00, Content: Def wouldn’t click proceed just on account of that fear mongering warning screen
# Timestamp: 2024-01-10T07:11:30.657000+00:00, Content: Yea that looks scary. Why not just use a desktop?
# Timestamp: 2024-01-10T07:11:14.930000+00:00, Content: gm
# Timestamp: 2024-01-10T07:09:12.842000+00:00, Content: Gm sean
# Timestamp: 2024-01-10T07:08:51.432000+00:00, Content: Gm sauce
# Timestamp: 2024-01-10T07:08:44.934000+00:00, Content: Gm pavil legend
# Timestamp: 2024-01-10T07:08:40.733000+00:00, Content: Gm rob
# Timestamp: 2024-01-10T07:08:22.565000+00:00, Content:
# Timestamp: 2024-01-10T06:53:22.731000+00:00, Content:
# Timestamp: 2024-01-10T06:50:36.555000+00:00, Content: I doubt it says that
# Timestamp: 2024-01-10T06:39:45.768000+00:00, Content:

# %%
import requests
import pandas as pd
from datetime import datetime

def retrieve_messages_with_user(channel_id, start_date, end_date):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }

    # Convert start_date and end_date to timestamp
    start_timestamp = int(datetime.strptime(start_date, '%Y-%m-%d').timestamp())
    end_timestamp = int(datetime.strptime(end_date, '%Y-%m-%d').timestamp())

    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    messages_data = []
    params = {
        'limit': 100,  # Number of messages per request, adjust as needed
    }

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break  # Break the loop if no more messages

            for message in json_data:
                timestamp = int(datetime.fromisoformat(message['timestamp']).timestamp())
                if start_timestamp <= timestamp <= end_timestamp:
                    content = message['content']
                    user_id = message['author']['id'] if 'author' in message else None  # Get user ID
                    messages_data.append({'Timestamp': message['timestamp'], 'Content': content, 'User_ID': user_id})

                # Stop if messages are beyond the target date range
                if timestamp < start_timestamp:
                    return messages_data

            params['before'] = json_data[-1]['id']  # Set the 'before' parameter for pagination
        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return []

    return messages_data

# Define the target date range for extraction
start_date = '2023-12-01'
end_date = '2024-01-31'

messages = retrieve_messages_with_user('867732042325688350', start_date, end_date)

# Convert retrieved messages to DataFrame
df = pd.DataFrame(messages)

# Export to Excel
file_name = 'discord_huddlemessages_dec2023_to_jan2024_with_users.xlsx'  # Change the file name if needed
df.to_excel(file_name, index=False)
print(f"Messages successfully saved to {file_name}")
# Out:
# Messages successfully saved to discord_huddlemessages_dec2023_to_jan2024_with_users.xlsx

# %%
import requests
import pandas as pd
from datetime import datetime

def retrieve_messages_with_user_within_date_range(channel_id, start_date, end_date):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }

    # Convert start_date and end_date to timestamp
    start_timestamp = int(datetime.strptime(start_date, '%Y-%m-%d').timestamp())
    end_timestamp = int(datetime.strptime(end_date, '%Y-%m-%d').timestamp())

    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    messages_data = []
    params = {
        'limit': 100,  # Number of messages per request, adjust as needed
    }

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break  # Break the loop if no more messages

            for message in json_data:
                timestamp = int(datetime.fromisoformat(message['timestamp']).timestamp())
                if start_timestamp <= timestamp <= end_timestamp:
                    content = message['content']
                    user_id = message['author']['id'] if 'author' in message else None  # Get user ID
                    messages_data.append({'Timestamp': message['timestamp'], 'Content': content, 'User_ID': user_id})

                # Stop if messages are beyond the target date range
                if timestamp < start_timestamp:
                    return messages_data

            params['before'] = json_data[-1]['id']  # Set the 'before' parameter for pagination
        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return []

    return messages_data

# Define the target date range for extraction
start_date = '2023-02-01'
end_date = '2023-05-31'

messages = retrieve_messages_with_user_within_date_range('867732042325688350', start_date, end_date)

# Convert retrieved messages to DataFrame
df = pd.DataFrame(messages)

# Export to Excel
file_name = 'discord_huddlemessages_feb2023_to_may2023_with_users.xlsx'  # Change the file name if needed
df.to_excel(file_name, index=False)
print(f"Messages successfully saved to {file_name}")
# Out:
# Messages successfully saved to discord_huddlemessages_feb2023_to_may2023_with_users.xlsx

# %%
import requests
import pandas as pd
from datetime import datetime

def retrieve_messages_with_user_within_date_range(channel_id, start_date, end_date):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }

    start_timestamp = int(datetime.strptime(start_date, '%Y-%m-%d').timestamp())
    end_timestamp = int(datetime.strptime(end_date, '%Y-%m-%d').timestamp())

    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    params = {'limit': 100}

    messages_data = []

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break

            for message in json_data:
                timestamp = int(datetime.fromisoformat(message['timestamp']).timestamp())
                if start_timestamp <= timestamp <= end_timestamp:
                    content = message['content']
                    user_id = message['author']['id'] if 'author' in message else None  # Get user ID
                    messages_data.append({'Timestamp': message['timestamp'], 'Content': content, 'User_ID': user_id})

            if json_data:
                params['before'] = json_data[-1]['id']

        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return

    df = pd.DataFrame(messages_data)
    file_name = 'discord_huddlemessages_jan2022_to_Apr2022_with_users.xlsx'
    df.to_excel(file_name, index=False)
    print(f"Messages successfully saved to {file_name}")

# Define the target date range for extraction
start_date = '2022-01-01'
end_date = '2022-04-30'

retrieve_messages_with_user_within_date_range('867732042325688350', start_date, end_date)

# %%
import requests
import pandas as pd
from datetime import datetime

def retrieve_messages_with_user_within_date_range(channel_id, start_date, end_date):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }

    start_timestamp = int(datetime.strptime(start_date, '%Y-%m-%d').timestamp())
    end_timestamp = int(datetime.strptime(end_date, '%Y-%m-%d').timestamp())

    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    params = {'limit': 100}

    messages_data = []

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break

            for message in json_data:
                timestamp = int(datetime.fromisoformat(message['timestamp']).timestamp())
                if start_timestamp <= timestamp <= end_timestamp:
                    content = message['content']
                    user_id = message['author']['id'] if 'author' in message else None  # Get user ID
                    messages_data.append({'Timestamp': message['timestamp'], 'Content': content, 'User_ID': user_id})

            if json_data:
                params['before'] = json_data[-1]['id']

        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return

    df = pd.DataFrame(messages_data)
    file_name = 'discord_huddlemessages_sep2021_to_dec2021_with_users.xlsx'
    df.to_excel(file_name, index=False)
    print(f"Messages successfully saved to {file_name}")

# Define the target date range for extraction
start_date = '2021-09-01'
end_date = '2021-12-31'

retrieve_messages_with_user_within_date_range('867732042325688350', start_date, end_date)
# Out:
# Messages successfully saved to discord_huddlemessages_sep2021_to_dec2021_with_users.xlsx

# %%
import requests
import pandas as pd
from datetime import datetime

def retrieve_messages_with_user_within_date_range(channel_id, start_date, end_date):
    headers = {
        'Authorization': 'MTE2NTk1NzY5MzcwMjQxODQ0Mw.GOmqj0.l9llP1irQfGlhpOWXvtqVyuBRivPwgosxAhqBA'  # Replace with your bot token
    }

    start_timestamp = int(datetime.strptime(start_date, '%Y-%m-%d').timestamp())
    end_timestamp = int(datetime.strptime(end_date, '%Y-%m-%d').timestamp())

    url = f'https://discord.com/api/v9/channels/{channel_id}/messages'
    params = {'limit': 100}

    messages_data = []

    while True:
        r = requests.get(url, headers=headers, params=params)
        if r.status_code == 200:
            json_data = r.json()
            if not json_data:
                break

            for message in json_data:
                timestamp = int(datetime.fromisoformat(message['timestamp']).timestamp())
                if start_timestamp <= timestamp <= end_timestamp:
                    content = message['content']
                    user_id = message['author']['id'] if 'author' in message else None  # Get user ID
                    messages_data.append({'Timestamp': message['timestamp'], 'Content': content, 'User_ID': user_id})

            if json_data:
                params['before'] = json_data[-1]['id']

        else:
            print(f"Failed to retrieve messages. Status code: {r.status_code}")
            return

    df = pd.DataFrame(messages_data)
    file_name = 'discord_huddlemessages_jun2021_to_aug2021_with_users.xlsx'
    df.to_excel(file_name, index=False)
    print(f"Messages successfully saved to {file_name}")

# Define the target date range for extraction
start_date = '2021-06-01'
end_date = '2021-08-30'

retrieve_messages_with_user_within_date_range('867732042325688350', start_date, end_date)
# Out:
# Messages successfully saved to discord_huddlemessages_jun2021_to_aug2021_with_users.xlsx
